# %%
from base import *

for cat in get_main_categories()[:3]:
    print(cat)
# Out:
# (id=t1, name=Lyd & Billede)
# (id=t2, name=Computer & Software)
# (id=t3, name=Hvidevarer)

# %%
category = Category(id='t9')
print(category)
# Out:
# (id=t9, name=Computer hardware)

# %%
subcategories = category.get_subcategories()
for subcat in subcategories[:3]:
    print(subcat)
# Out:
# (id=cl40, name=CPUs)
# (id=cl37, name=Grafikkort)
# (id=cl186, name=Kabinetter)

# %%
subCategory = SubCategory(id='cl40')

filters = subCategory.get_filters()
for filter in filters[:3]:
    print(filter)
# Out:
# Filter(id=PRICE, name=Pris)
# Filter(id=BRAND, name=Mærke)
# Filter(id=RATING, name=Vurdering)

# %%
filter = Filter(id='BRAND', subcategory=subCategory)
filter_keys = filter.get_keys()
for key in filter_keys[:3]:
    print(key)
# Out:
# {'key': '179629', 'optionId': 179629, 'count': 2, 'optionValue': 'ABB', 'optionImage': None}
# {'key': '176', 'optionId': 176, 'count': 1, 'optionValue': 'Acer', 'optionImage': None}
# {'key': '509', 'optionId': 509, 'count': 303, 'optionValue': 'AMD', 'optionImage': None}

# %%
products = subCategory.get_products(query='af_BRAND=509&size=1')
print(json.dumps(products, indent=4))
# Out:
# {
#     "totalProductHits": 303,
#     "totalCategoryOfferHits": 0,
#     "clickableCategoryOfferHits": 0,
#     "subCategoryLevel": null,
#     "products": [
#         {
#             "id": "3205665051",
#             "name": "AMD Ryzen 7 7800X3D 4.2GHz Socket AM5 Box",
#             "description": "AMD Socket AM5",
#             "url": "/pl/40-3205665051/CPUs/AMD-Ryzen-7-7800X3D-4.2GHz-Socket-AM5-Box-Sammenlign-Priser",
#             "lowestPrice": {
#                 "amount": "3309.00",
#                 "currency": "DKK"
#             },
#             "image": {
#                 "id": "3009863292",
#                 "url": null,
#                 "path": "/product/3009863292/AMD-Ryzen-7-7800X3D-4.2GHz-Socket-AM5-Box.jpg",
#                 "description": "AMD Ryzen 7 7800X3D 4.2GHz Socket AM5 Box"
#             },
#             "filterHits": [],
#             "rank": {
#                 "rank": 1,
#                 "trend": "NEUTRAL"
#             },
#             "brand": {
#                 "id": "509",
#                 "name": "AMD",
#                 "image": null
#             },
#             "rating": {
#                 "numberOfRatings": 635,
#                 "averageRating": "4.9",
#                 "count": 635,
#                 "average": "4.9"
#             },
#             "priceDrop": null,
#             "ribbon": {
#                 "type": "WATCHED",
#                 "value": "500+",
#                 "description": null
#             },
#             "productGroup": null,
#             "cheapestOffer": {
#                 "id": "f6e7738ec2032442b4c0002664642b18",
#                 "price": {
#                     "amount": "3309.00",
#                     "currency": "DKK"
#                 },
#                 "url": "/gotostore/v1/DK/f6e7738ec2032442b4c0002664642b18",
#                 "merchant": {
#                     "id": "38858",
#                     "name": "BWS Computers",
#                     "image": null
#                 },
#                 "pricePerUnit": null
#             },
#             "classification": "ONE",
#             "previewMerchants": {
#                 "count": 17,
#                 "merchants": [
#                     {
#                         "id": "589",
#                         "name": "ComputerSalg",
#                         "image": {
#                             "id": null,
#                             "url": null,
#                             "path": "/images/brenda/1ca49cba3c85d7cf1d680a29c5240147.png",
#                             "description": "ComputerSalg"
#                         },
#                         "clickable": true
#                     },
#                     {
#                         "id": "1325",
#                         "name": "CompuMail",
#                         "image": {
#                             "id": null,
#                             "url": null,
#                             "path": "/images/brenda/f1942ace186689d38597f5a7210f4e41.jpg",
#                             "description": "CompuMail"
#                         },
#                         "clickable": true
#                     },
#                     {
#                         "id": "2957",
#                         "name": "Proshop.dk",
#                         "image": {
#                             "id": null,
#                             "url": null,
#                             "path": "/images/brenda/a70445043a953dc37f3359befc8254c2.png",
#                             "description": "Proshop.dk"
#                         },
#                         "clickable": true
#                     }
#                 ]
#             },
#             "installmentPrice": null
#         }
#     ],
#     "categoryOffers": [],
#     "categoryPaths": [
#         {
#             "id": "2",
#             "name": "Computer & Software",
#             "url": "/t/2/Computer-Software"
#         },
#         {
#             "id": "9",
#             "name": "Computer hardware",
#             "url": "/t/9/Computer-hardware"
#         },
#         {
#             "id": "40",
#             "name": "CPUs",
#             "url": "/cl/40/CPUs"
#         }
#     ],
#     "filterCategory": null,
#     "popularSubcategories": [],
#     "quickFilters": [
#         {
#             "id": "60498110",
#             "name": "Sokkel",
#             "unit": null,
#             "options": [
#                 {
#                     "id": "507126",
#                     "value": "AMD Socket AM5",
#                     "from": null,
#                     "to": null,
#                     "count": 41,
#                     "image": null
#                 },
#                 {
#                     "id": "60498114",
#                     "value": "AMD Socket AM4",
#                     "from": null,
#                     "to": null,
#                     "count": 68,
#                     "image": null
#                 },
#                 {
#                     "id": "60498148",
#                     "value": "AMD Socket SP3",
#                     "from": null,
#                     "to": null,
#                     "count": 95,
#                     "image": null
#                 },
#                 {
#                     "id": "60540184",
#                     "value": "AMD Socket sWRX8",
#                     "from": null,
#                     "to": null,
#                     "count": 8,
#                     "image": null
#                 },
#                 {
#                     "id": "507850",
#                     "value": "AMD Socket SP5",
#                     "from": null,
#                     "to": null,
#                     "count": 3,
#                     "image": null
#                 }
#             ],
#             "type": "OPTIONS",
#             "minimum": null,
#             "maximum": null
#         },
#         {
#             "id": "60498188",
#             "name": "AMD Series",
#             "unit": null,
#             "options": [
#                 {
#                     "id": "60498193",
#                     "value": "Ryzen 7",
#                     "from": null,
#                     "to": null,
#                     "count": 26,
#                     "image": null
#                 },
#                 {
#                     "id": "60498191",
#                     "value": "Ryzen 9",
#                     "from": null,
#                     "to": null,
#                     "count": 19,
#                     "image": null
#                 },
#                 {
#                     "id": "60498195",
#                     "value": "Ryzen 5",
#                     "from": null,
#                     "to": null,
#                     "count": 41,
#                     "image": null
#                 },
#                 {
#                     "id": "60498215",
#                     "value": "EPYC",
#                     "from": null,
#                     "to": null,
#                     "count": 126,
#                     "image": null
#                 },
#                 {
#                     "id": "60498190",
#                     "value": "Ryzen 9 Pro",
#                     "from": null,
#                     "to": null,
#                     "count": 1,
#                     "image": null
#                 }
#             ],
#             "type": "OPTIONS",
#             "minimum": null,
#             "maximum": null
#         }
#     ],
#     "productDeals": {
#         "id": "cl40",
#         "name": "Tilbud",
#         "anchor": "AMD CPUs p\u00e5 tilbud",
#         "url": "/cl/40/CPUs?man_id=509&features=sale",
#         "description": null,
#         "productCount": 13,
#         "products": [
#             {
#                 "id": "3313281531",
#                 "name": "AMD Ryzen 7 8700F 4.1GHz Socket AM5 Tray",
#                 "description": "AMD Socket AM5, 2024",
#                 "url": "/gotostore/v1/DK/4783668cb8dfe79e00271b54e41802a5?productId=3313281531",
#                 "lowestPrice": {
#                     "amount": "1339.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3122616666",
#                     "url": null,
#                     "path": "/product/3122616666/AMD-Ryzen-7-8700F-4.1GHz-Socket-AM5-Tray.jpg",
#                     "description": "AMD Ryzen 7 8700F 4.1GHz Socket AM5 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 38,
#                     "trend": "NEGATIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "1491.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "10.19"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "151.93",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "4783668cb8dfe79e00271b54e41802a5",
#                     "price": {
#                         "amount": "1339.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/4783668cb8dfe79e00271b54e41802a5",
#                     "merchant": {
#                         "id": "27750",
#                         "name": "happii.dk",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "3299652515",
#                 "name": "AMD Ryzen 5 8400F 4.2GHz Socket AM5 Box",
#                 "description": "AMD Socket AM5, 2024",
#                 "url": "/gotostore/v1/DK/ffd599ceb79704952afd9ccba4fbb9ca?productId=3299652515",
#                 "lowestPrice": {
#                     "amount": "1174.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3105694902",
#                     "url": null,
#                     "path": "/product/3105694902/AMD-Ryzen-5-8400F-4.2GHz-Socket-AM5-Box.jpg",
#                     "description": "AMD Ryzen 5 8400F 4.2GHz Socket AM5 Box"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 42,
#                     "trend": "POSITIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "1319.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "10.99"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "144.96",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "ffd599ceb79704952afd9ccba4fbb9ca",
#                     "price": {
#                         "amount": "1174.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/ffd599ceb79704952afd9ccba4fbb9ca",
#                     "merchant": {
#                         "id": "1325",
#                         "name": "CompuMail",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "3203361233",
#                 "name": "AMD Ryzen 5 4500 3.6GHz Socket AM4 Tray",
#                 "description": "AMD Socket AM4, 2022",
#                 "url": "/gotostore/v1/DK/2a196141791acbe01acd897dd7a1f4ae?productId=3203361233",
#                 "lowestPrice": {
#                     "amount": "872.50",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3008758635",
#                     "url": null,
#                     "path": "/product/3008758635/AMD-Ryzen-5-4500-3.6GHz-Socket-AM4-Tray.jpg",
#                     "description": "AMD Ryzen 5 4500 3.6GHz Socket AM4 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": null,
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "1161.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "24.85"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "288.51",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "2a196141791acbe01acd897dd7a1f4ae",
#                     "price": {
#                         "amount": "872.50",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/2a196141791acbe01acd897dd7a1f4ae",
#                     "merchant": {
#                         "id": "283860",
#                         "name": "Bittech IT",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "3200124302",
#                 "name": "AMD Epyc 7453 2.75GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3, 2021",
#                 "url": "/gotostore/v1/DK/027dad0ee899f56f133d4eaa7eafa1c5?productId=3200124302",
#                 "lowestPrice": {
#                     "amount": "6098.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3001368033",
#                     "url": null,
#                     "path": "/product/3001368033/AMD-Epyc-7453-2.75GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7453 2.75GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": null,
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "12379.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "50.74"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "6281.10",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "027dad0ee899f56f133d4eaa7eafa1c5",
#                     "price": {
#                         "amount": "6098.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/027dad0ee899f56f133d4eaa7eafa1c5",
#                     "merchant": {
#                         "id": "27750",
#                         "name": "happii.dk",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "3200124286",
#                 "name": "AMD Epyc 7343 3.2GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3, 2021",
#                 "url": "/gotostore/v1/DK/f40ce94bbbd8d4e2c104e64e4a4c840a?productId=3200124286",
#                 "lowestPrice": {
#                     "amount": "4526.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3001367935",
#                     "url": null,
#                     "path": "/product/3001367935/AMD-Epyc-7343-3.2GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7343 3.2GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 227,
#                     "trend": "NEGATIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "7213.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "37.25"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "2686.84",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "f40ce94bbbd8d4e2c104e64e4a4c840a",
#                     "price": {
#                         "amount": "4526.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/f40ce94bbbd8d4e2c104e64e4a4c840a",
#                     "merchant": {
#                         "id": "27750",
#                         "name": "happii.dk",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "5309314",
#                 "name": "AMD Epyc 7742 2.25GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3, 2019",
#                 "url": "/gotostore/v1/DK/a0491e1ff771d66d67eebf9e51a0bd2c?productId=5309314",
#                 "lowestPrice": {
#                     "amount": "9735.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3000680117",
#                     "url": null,
#                     "path": "/product/3000680117/AMD-Epyc-7742-2.25GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7742 2.25GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 306,
#                     "trend": "POSITIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "11275.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "13.66"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "1540.17",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "a0491e1ff771d66d67eebf9e51a0bd2c",
#                     "price": {
#                         "amount": "9735.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/a0491e1ff771d66d67eebf9e51a0bd2c",
#                     "merchant": {
#                         "id": "19414",
#                         "name": "DataWorld",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "5291319",
#                 "name": "AMD Epyc 7302P 3.0GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3, 2019",
#                 "url": "/gotostore/v1/DK/0e8845f25dc14b42f7d188cd9ae3856c?productId=5291319",
#                 "lowestPrice": {
#                     "amount": "2921.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3000616804",
#                     "url": null,
#                     "path": "/product/3000616804/AMD-Epyc-7302P-3.0GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7302P 3.0GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 418,
#                     "trend": "POSITIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "5657.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "48.36"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "2735.73",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "0e8845f25dc14b42f7d188cd9ae3856c",
#                     "price": {
#                         "amount": "2921.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/0e8845f25dc14b42f7d188cd9ae3856c",
#                     "merchant": {
#                         "id": "19414",
#                         "name": "DataWorld",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "3254499588",
#                 "name": "AMD Ryzen 5 5500GT CPU 3.6 GHz Processor 6 kerner med 12 tr\u00e5de 16 mb cache",
#                 "description": null,
#                 "url": "/gotostore/v1/DK/7885d6267c573461c8a9a1b7ee7cab39?productId=3254499588",
#                 "lowestPrice": {
#                     "amount": "929.00",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3059983979",
#                     "url": null,
#                     "path": "/product/3059983979/AMD-Ryzen-5-5500GT-CPU-3.6-GHz-Processor-6-kerner-med-12-traade-16-mb-cache.jpg",
#                     "description": "AMD Ryzen 5 5500GT CPU 3.6 GHz Processor 6 kerner med 12 tr\u00e5de 16 mb cache"
#                 },
#                 "filterHits": [],
#                 "rank": null,
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "1037.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "10.41"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "107.95",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "7885d6267c573461c8a9a1b7ee7cab39",
#                     "price": {
#                         "amount": "929.00",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/7885d6267c573461c8a9a1b7ee7cab39",
#                     "merchant": {
#                         "id": "1325",
#                         "name": "CompuMail",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "5308953",
#                 "name": "AMD Epyc 7702P 2.0GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3",
#                 "url": "/gotostore/v1/DK/b1749d71688eeb611146757adbca677d?productId=5308953",
#                 "lowestPrice": {
#                     "amount": "32246.25",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3000678824",
#                     "url": null,
#                     "path": "/product/3000678824/AMD-Epyc-7702P-2.0GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7702P 2.0GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 420,
#                     "trend": "POSITIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "36853.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "12.50"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "4606.63",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "b1749d71688eeb611146757adbca677d",
#                     "price": {
#                         "amount": "32246.25",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/b1749d71688eeb611146757adbca677d",
#                     "merchant": {
#                         "id": "283860",
#                         "name": "Bittech IT",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             },
#             {
#                 "id": "5309374",
#                 "name": "AMD Epyc 7542 2.9GHz Socket SP3 Tray",
#                 "description": "AMD Socket SP3, 2019",
#                 "url": "/gotostore/v1/DK/4aa2d08d37832b294fd97785f77281af?productId=5309374",
#                 "lowestPrice": {
#                     "amount": "15582.50",
#                     "currency": "DKK"
#                 },
#                 "image": {
#                     "id": "3000680306",
#                     "url": null,
#                     "path": "/product/3000680306/AMD-Epyc-7542-2.9GHz-Socket-SP3-Tray.jpg",
#                     "description": "AMD Epyc 7542 2.9GHz Socket SP3 Tray"
#                 },
#                 "filterHits": [],
#                 "rank": {
#                     "rank": 417,
#                     "trend": "NEGATIVE"
#                 },
#                 "brand": null,
#                 "rating": {
#                     "numberOfRatings": 0,
#                     "averageRating": "0.0",
#                     "count": 0,
#                     "average": "0.0"
#                 },
#                 "priceDrop": {
#                     "oldPrice": {
#                         "amount": "19468.00",
#                         "currency": "DKK"
#                     },
#                     "percent": "19.96"
#                 },
#                 "ribbon": {
#                     "type": "PRICE_DROP_ABSOLUTE",
#                     "value": "3885.81",
#                     "description": null
#                 },
#                 "productGroup": null,
#                 "cheapestOffer": {
#                     "id": "4aa2d08d37832b294fd97785f77281af",
#                     "price": {
#                         "amount": "15582.50",
#                         "currency": "DKK"
#                     },
#                     "url": "/gotostore/v1/DK/4aa2d08d37832b294fd97785f77281af",
#                     "merchant": {
#                         "id": "283860",
#                         "name": "Bittech IT",
#                         "image": null
#                     },
#                     "pricePerUnit": null
#                 },
#                 "classification": "UNCLASSIFIED",
#                 "previewMerchants": {
#                     "count": 0,
#                     "merchants": []
#                 },
#                 "installmentPrice": null
#             }
#         ]
#     },
#     "buyingGuidesQuestion": null
# }

# %%
result = search("cpu")
print(json.dumps(result, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = search("cpu")
#       2 print(json.dumps(result, indent=4))
#
# NameError: name 'search' is not defined
